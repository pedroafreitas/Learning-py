# %%
"""
Problem Set 0:

Saves two numbers given by the user as 'x'and 'y'
Print out number 'x' raised to the power of 'y'
"""
import numpy

x = input('Enter number \"x":')
y = input('Enter number \"y":')

x = int(x)
y = int(y)
print('X**y = {}'.format(x**y))
print('log(x) = {}'.format(int(numpy.log2(x))))
# Out:
# Enter number "x":2
# Enter number "y":3
# X**y = 8
# log(x) = 1

# %%
"""
Problem Set 1:


"""

portion_down_payment = 0.25
currant_saving = 0
r = 0.04

annual_salary = input('Enter your annual salary: ')
portion_saved = input('Enter the percent of your salary to save, as decimal: ')
total_cost = input('Enter the cost of your dream home: ')
int(annual_salary)
int(portion_saved)
int(total_cost)
# Out:
# '\nProblem Set 1:\n\n\n'
